# %%
# %pylab
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
hm_height= 7
hm_width = 5

bc_x = 3/hm_width
bc_y = 2/hm_height

# %%
indices = np.indices((hm_height,hm_width)).astype(np.float32)
indices[0] /= hm_height
indices[1] /= hm_width

# %%
indices
# Out:
# array([[[0.        , 0.        , 0.        , 0.        , 0.        ],
#         [0.14285715, 0.14285715, 0.14285715, 0.14285715, 0.14285715],
#         [0.2857143 , 0.2857143 , 0.2857143 , 0.2857143 , 0.2857143 ],
#         [0.42857143, 0.42857143, 0.42857143, 0.42857143, 0.42857143],
#         [0.5714286 , 0.5714286 , 0.5714286 , 0.5714286 , 0.5714286 ],
#         [0.71428573, 0.71428573, 0.71428573, 0.71428573, 0.71428573],
#         [0.85714287, 0.85714287, 0.85714287, 0.85714287, 0.85714287]],
#
#        [[0.        , 0.2       , 0.4       , 0.6       , 0.8       ],
#         [0.        , 0.2       , 0.4       , 0.6       , 0.8       ],
#         [0.        , 0.2       , 0.4       , 0.6       , 0.8       ],
#         [0.        , 0.2       , 0.4       , 0.6       , 0.8       ],
#         [0.        , 0.2       , 0.4       , 0.6       , 0.8       ],
#         [0.        , 0.2       , 0.4       , 0.6       , 0.8       ],
# ...

# %%
indices[0] -= bc_y
indices[1] -= bc_x

# %%
indices.shape
# Out:
# (2, 7, 5)

# %%
rep = np.stack((indices,)*3)

# %%
rep = rep.reshape(-1,hm_height,hm_width)

# %%
rep.shape
# Out:
# (6, 7, 5)

# %%
rep
# Out:
# array([[[-0.2857143 , -0.2857143 , -0.2857143 , -0.2857143 ,
#          -0.2857143 ],
#         [-0.14285715, -0.14285715, -0.14285715, -0.14285715,
#          -0.14285715],
#         [ 0.        ,  0.        ,  0.        ,  0.        ,
#           0.        ],
#         [ 0.14285713,  0.14285713,  0.14285713,  0.14285713,
#           0.14285713],
#         [ 0.2857143 ,  0.2857143 ,  0.2857143 ,  0.2857143 ,
#           0.2857143 ],
#         [ 0.42857143,  0.42857143,  0.42857143,  0.42857143,
#           0.42857143],
#         [ 0.57142854,  0.57142854,  0.57142854,  0.57142854,
#           0.57142854]],
#
#        [[-0.6       , -0.40000004, -0.20000002,  0.        ,
#           0.19999999],
#         [-0.6       , -0.40000004, -0.20000002,  0.        ,
#           0.19999999],
#         [-0.6       , -0.40000004, -0.20000002,  0.        ,
#           0.19999999],
#         [-0.6       , -0.40000004, -0.20000002,  0.        ,
#           0.19999999],
# ...
